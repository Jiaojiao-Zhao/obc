# %%
import folium
from folium.features import DivIcon
import base64
from folium import IFrame

suzhou_coords = [31.40374, 120.92504]
m = folium.Map(location=suzhou_coords, zoom_start=14)

# %%
site_1 = [31.38896807679732, 120.9220200006602]

with open("pictures/很久以前.png", "rb") as image_file:
    encoded1 = base64.b64encode(image_file.read()).decode('utf-8')

html1 = f"""
<div style="
    font-family: 'Noto Sans SC', 'Helvetica Neue', Arial, sans-serif;
    max-width: 360px;
    background: linear-gradient(145deg, #fff8f0, #ffe1cc);
    border-radius: 18px;
    padding: 20px;
    box-shadow: 0 12px 28px rgba(0,0,0,0.12);
    color: #2b2926;
">
  <div style="display: flex; gap: 16px; align-items: center; margin-bottom: 14px;">
    <img src="data:image/png;base64,{encoded1}"
         alt="很久以前烧烤门店"
         style="width: 120px; height: 120px; object-fit: cover;
                border-radius: 14px; box-shadow: 0 8px 18px rgba(0,0,0,0.18);" />
    <div>
      <p style="margin: 0; font-size: 11px; letter-spacing: 0.3em;
                color: #b45309; text-transform: uppercase;">必吃烧烤</p>
      <h4 style="margin: 4px 0 0; font-size: 20px; line-height: 1.3;">
        很久以前<br><span style="font-size: 14px; color: #a15c11;">Long Time Ago</span>
      </h4>
      <p style="margin: 6px 0 0; font-size: 12px; color: #8c5525;">
        推荐指数 / Rating:
        <span style="font-size: 14px; color: #f7b500;">★ ★ ★ ★ ★</span>
      </p>
    </div>
  </div>
  <div style="font-size: 14px; line-height: 1.7;">
    <p style="margin: 0 0 10px;">
      “很久以前”是一家专注于呼伦贝尔羊肉串的烧烤连锁店，以炭火精烤和稳定美味著称。
      时常客满、广受欢迎，是朋友聚餐和宵夜的热门选择。
      “Long Time Ago” is a barbecue chain specializing in Hulunbuir lamb skewers, renowned for
      charcoal grilling and consistent flavor—packed most nights and perfect for group dinners or late-night bites.
    </p>
    <p style="margin: 0;"><strong>地理位置 Location:</strong> 昆山万象汇嗨街一层 · 1F, Vanke Mall Hi Street, Kunshan</p>
    <p style="margin: 6px 0 0;"><strong>推荐原因 Why go:</strong> 羊肉品质很高，是昆杜学生在万象汇吃饭的首选之一。
      Premium lamb quality—top pick among Duke Kunshan students eating at Vanke Mall.</p>
    <p style="margin: 6px 0 0;"><strong>必吃菜品 Must-try:</strong> 呼伦贝尔羊肉串 Hulunbuir lamb skewers；
      烤生蚝 Charcoal-grilled oysters.</p>
    <p style="margin: 6px 0 0;"><strong>人均 Per person:</strong> ¥90</p>
    <p style="margin: 6px 0 0;"><strong>美团 Meituan:</strong> <a href="https://m.dianping.com/shopinfo/k22X9dVtEs4605vA?msource=Appshare2021&utm_source=shop_share&shoptype=10&shopcategoryid=4449&cityid=416&isoversea=0" target="_blank">@大众点评</a></p>
  </div>
</div>
"""

iframe1 = IFrame(html1, width=300, height=300)
popup1 = folium.Popup(iframe1, max_width=2500)

from folium.features import CustomIcon

logo_icon = CustomIcon(
    icon_image="pictures/long_time_ago_logo.png",  # 你的 logo 路径
    icon_size=(32, 32),        # 根据图片比例调整
    icon_anchor=(16,16)       # 控制“指针”位置
)

folium.Marker(
    location=site_1,
    popup=popup1,
    tooltip="很久以前 Long Time Ago",
    icon=logo_icon
).add_to(m)

# %%
site_2 = [31.413638, 120.894177]

with open("pictures/蟹王府.jpg", "rb") as image_file:
    encoded2 = base64.b64encode(image_file.read()).decode('utf-8')

html2 = f"""
<div style="
    font-family: 'Noto Sans SC', 'Helvetica Neue', Arial, sans-serif;
    max-width: 360px;
    background: linear-gradient(145deg, #f0faff, #dff3ff);
    border-radius: 18px;
    padding: 20px;
    box-shadow: 0 12px 28px rgba(0,0,0,0.12);
    color: #1b3a4b;
">
  <div style="display: flex; gap: 16px; align-items: center; margin-bottom: 14px;">
    <img src="data:image/png;base64,{encoded2}"
         alt="蟹王府"
         style="width: 120px; height: 120px; object-fit: cover;
                border-radius: 14px; box-shadow: 0 8px 18px rgba(0,0,0,0.18);" />
    <div>
      <p style="margin: 0; font-size: 11px; letter-spacing: 0.3em;
                color: #0c5a95; text-transform: uppercase;">大闸蟹</p>
      <h4 style="margin: 4px 0 0; font-size: 20px; line-height: 1.3;">
        蟹王府<br><span style="font-size: 14px; color: #0c5a95;">King of Crab</span>
      </h4>
      <p style="margin: 6px 0 0; font-size: 12px; color: #0e4a70;">
        推荐指数 / Rating:
        <span style="font-size: 14px; color: #ffa600;">★ ★ ★ ☆ ☆</span>
      </p>
    </div>
  </div>

  <div style="font-size: 14px; line-height: 1.7;">
    <p style="margin: 0 0 10px;">
      “蟹王府”以一年四季均能吃到大闸蟹闻名，是连续六年获得米其林一星的餐厅。
      招牌蟹宴风味浓郁、食材扎实，非常适合聚餐或犒劳自己。
      Xie Wang Fu is known for premium hairy crabs over all seasons, it has been awarded a Michelin star for six consecutive years.
    </p>

    <p style="margin: 0;"><strong>地理位置 Location:</strong> 大渔湾 · Dayu Bay Commercial Area</p>
    <p style="margin: 6px 0 0;"><strong>推荐原因 Why go:</strong> 大闸蟹品质好， 适合家庭聚会。It has high-quality freshwater crabs, making it suitable for family gatherings.</p>
    <p style="margin: 6px 0 0;"><strong>必吃菜品 Must-try:</strong> 清蒸大闸蟹 Steamed hairy crab; 蟹粉小笼 Soup dumplings with crab roe</p>
    <p style="margin: 6px 0 0;"><strong>人均 Per person:</strong> ¥198</p>
    <p style="margin: 6px 0 0;"><strong>美团 Meituan:</strong> <a href="https://m.dianping.com/shopinfo/l3OykiFQbnmnmjSp?msource=Appshare2021&utm_source=shop_share&shoptype=10&shopcategoryid=203&cityid=416&isoversea=0" target="_blank">@大众点评</a></p>
  </div>
</div>
"""

iframe2 = IFrame(html2, width=300, height=300)
popup2 = folium.Popup(iframe2, max_width=2500)

from folium.features import CustomIcon

icon2 = CustomIcon(
    icon_image="pictures/xie_wang_fu_logo.png",  # 你的 logo 路径
    icon_size=(35, 20),        # 根据图片比例调整
    icon_anchor=(17.5,10)       # 控制“指针”位置
)

# 如果你有 logo，则改成（取消注释）：
# logo2 = CustomIcon("pictures/xiewangfu_logo.png", icon_size=(32,32), icon_anchor=(16,16))

folium.Marker(
    location=site_2,
    popup=popup2,
    tooltip="蟹王府 King of Crab",
    icon=icon2   # 或者 logo2
).add_to(m)

# %%
site_3 = [31.388291, 120.942672]

with open("pictures/AMPM_fixed.png", "rb") as image_file:
    encoded3 = base64.b64encode(image_file.read()).decode('utf-8')

html3 = f"""
<div style="
    font-family: 'Noto Sans SC', 'Helvetica Neue', Arial, sans-serif;
    max-width: 360px;
    background: linear-gradient(145deg, #f5f8ff, #e8f2ff);
    border-radius: 18px;
    padding: 20px;
    box-shadow: 0 12px 28px rgba(0,0,0,0.12);
    color: #2c3e50;
">
  <div style="display: flex; gap: 16px; align-items: center; margin-bottom: 14px;">
    <img src="data:image/png;base64,{encoded3}"
         alt="AMPM Cafe&Brunch"
         style="width: 120px; height: 120px; object-fit: cover;
                border-radius: 14px; box-shadow: 0 8px 18px rgba(0,0,0,0.18);" />
    <div>
      <p style="margin: 0; font-size: 11px; letter-spacing: 0.3em;
                color: #3498db; text-transform: uppercase;">咖啡早午餐</p>
      <h4 style="margin: 4px 0 0; font-size: 20px; line-height: 1.3;">
        AMPM Cafe<br><span style="font-size: 14px; color: #3498db;">Cafe & Brunch</span>
      </h4>
      <p style="margin: 6px 0 0; font-size: 12px; color: #34495e;">
        推荐指数 / Rating:
        <span style="font-size: 14px; color: #f39c12;">★ ★ ★ ★ ☆</span>
      </p>
    </div>
  </div>

  <div style="font-size: 14px; line-height: 1.7;">
    <p style="margin: 0 0 10px;">
      AMPM Cafe&Brunch是一家提供全日早午餐和咖啡的休闲餐厅，氛围轻松惬意。
      AMPM Cafe&Brunch in Kunshan is a cozy casual restaurant serving all-day brunch and coffee.
    </p>

    <p style="margin: 0;"><strong>地理位置 Location:</strong> 大西门商业街 Daximen Commercial Street</p>
    <p style="margin: 6px 0 0;"><strong>推荐原因 Why go:</strong> 就餐氛围好，餐厅出品稳定，晚上有乐队表演 The dining atmosphere is excellent, the food quality is consistently good, and there is live band performance in the evenings.</p>
    <p style="margin: 6px 0 0;"><strong>必吃菜品 Must-try:</strong> 松露薯条 Truffle Fries; 辣芝士牛肉烤饼 Spicy Cheese Beef Naan</p>
    <p style="margin: 6px 0 0;"><strong>人均 Per person:</strong> ¥115</p>
    <p style="margin: 6px 0 0;"><strong>美团 Meituan:</strong> <a href="https://m.dianping.com/shopinfo/l8T9KJhLnUAtwquK?msource=Appshare2021&utm_source=shop_share&shoptype=10&shopcategoryid=116&cityid=416&isoversea=0" target="_blank">@大众点评</a></p>
  </div>
</div>
"""

iframe3 = IFrame(html3, width=300, height=300)
popup3 = folium.Popup(iframe3, max_width=2500)

from folium.features import CustomIcon

icon3 = CustomIcon(
    icon_image="pictures/ampm_logo.jpg",  # 你的 logo 路径
    icon_size=(32, 32),        # 根据图片比例调整
    icon_anchor=(16, 16)       # 控制"指针"位置
)

folium.Marker(
    location=site_3,
    popup=popup3,
    tooltip="AMPM Cafe&Brunch",
    icon=icon3
).add_to(m)

# %%
site_4 = [31.407038, 120.952177]

with open("pictures/海底捞.jpg", "rb") as image_file:
    encoded4 = base64.b64encode(image_file.read()).decode('utf-8')

html4 = f"""
<div style="
    font-family: 'Noto Sans SC', 'Helvetica Neue', Arial, sans-serif;
    max-width: 360px;
    background: linear-gradient(145deg, #fff3f5, #ffe4e8);
    border-radius: 18px;
    padding: 20px;
    box-shadow: 0 12px 28px rgba(0,0,0,0.12);
    color: #4a1f28;
">
  <div style="display: flex; gap: 16px; align-items: center; margin-bottom: 14px;">
    <img src="data:image/png;base64,{encoded4}"
         alt="海底捞"
         style="width: 120px; height: 120px; object-fit: cover;
                border-radius: 14px; box-shadow: 0 8px 18px rgba(0,0,0,0.18);" />
    <div>
      <p style="margin: 0; font-size: 11px; letter-spacing: 0.3em;
                color: #c21f30; text-transform: uppercase;">火锅 HOTPOT</p>
      <h4 style="margin: 4px 0 0; font-size: 20px; line-height: 1.3;">
        海底捞<br><span style="font-size: 14px; color: #c21f30;">Haidilao Hotpot</span>
      </h4>
      <p style="margin: 6px 0 0; font-size: 12px; color: #8e3a45;">
        推荐指数 / Rating:
        <span style="font-size: 14px; color: #ff4d4f;">★ ★ ★ ★ ★</span>
      </p>
    </div>
  </div>

  <div style="font-size: 14px; line-height: 1.7;">
    <p style="margin: 0 0 10px;">
      海底捞以贴心服务与稳定品质著称，是中国最受欢迎的火锅品牌之一。
      无论是深夜宵夜、好友聚餐还是生日庆祝，都能享受到超高服务体验。
      Haidilao is known nationwide for consistent hotpot quality and exceptional service.
    </p>

    <p style="margin: 0;"><strong>地理位置 Location:</strong> 招商花园城 5 层 · C-Mall 5F </p>

    <p style="margin: 6px 0 0;"><strong>推荐原因 Why go:</strong> 适合各种聚餐，特定时段中国大学生 69 折优惠，并且营业至深夜。
      Great choice for group gatherings, late-night dining, and student discounts.</p>

    <p style="margin: 6px 0 0;"><strong>必吃菜品 Must-try:</strong>
      番茄汤底 Tomato broth; 虾滑 Shrimp paste; 肥牛 Beef slices; 捞面 Laomian noodles
    </p>

    <p style="margin: 6px 0 0;"><strong>人均 Per person:</strong> ¥109</p>

    <p style="margin: 6px 0 0;"><strong>美团 Meituan:</strong>
      <a href="https://m.dianping.com/shopinfo/l69GiT5ziWpNm79w?msource=Appshare2021&utm_source=shop_share&shoptype=10&shopcategoryid=3023&cityid=416&isoversea=0" target="_blank">@大众点评</a>
    </p>
  </div>
</div>
"""

iframe4 = IFrame(html4, width=300, height=300)
popup4 = folium.Popup(iframe4, max_width=2500)

from folium.features import CustomIcon

icon4 = CustomIcon(
    icon_image="pictures/haidilao_logo.jpg",  # 如果有海底捞 logo 放这里
    icon_size=(30, 30),
    icon_anchor=(15,15)
)

# 若没有 logo，可暂时用数字图标（取消注释）
# icon4 = DivIcon(
#     icon_size=(30, 30),
#     icon_anchor=(15, 15),
#     html='<div style="font-size: 16pt; color: black;"><b>4</b></div>'
# )

folium.Marker(
    location=site_4,
    popup=popup4,
    tooltip="海底捞 Haidilao Hotpot",
    icon=icon4
).add_to(m)

# %%
site_5 = [31.404118, 120.904801]

with open("pictures/SHARK_fixed.png", "rb") as image_file:
    encoded5 = base64.b64encode(image_file.read()).decode('utf-8')

html5 = f"""
<div style="
    font-family: 'Noto Sans SC', 'Helvetica Neue', Arial, sans-serif;
    max-width: 360px;
    background: linear-gradient(145deg, #f5f8ff, #e8f2ff);
    border-radius: 18px;
    padding: 20px;
    box-shadow: 0 12px 28px rgba(0,0,0,0.12);
    color: #2c3e50;
">
  <div style="display: flex; gap: 16px; align-items: center; margin-bottom: 14px;">
    <img src="data:image/png;base64,{encoded5}"
         alt="SHARKBURGER"
         style="width: 120px; height: 120px; object-fit: cover;
                border-radius: 14px; box-shadow: 0 8px 18px rgba(0,0,0,0.18);" />
    <div>
      <p style="margin: 0; font-size: 11px; letter-spacing: 0.3em;
                color: #3498db; text-transform: uppercase;">美式快餐</p>
      <h4 style="margin: 4px 0 0; font-size: 20px; line-height: 1.3;">
        SHARKBURGER<br><span style="font-size: 14px; color: #3498db;">American Fastfood</span>
      </h4>
      <p style="margin: 6px 0 0; font-size: 12px; color: #34495e;">
        推荐指数 / Rating:
        <span style="font-size: 14px; color: #f39c12;">★ ★ ★ ★ ☆</span>
      </p>
    </div>
  </div>

  <div style="font-size: 14px; line-height: 1.7;">
    <p style="margin: 0 0 10px;">
      SHARKBURGER专注制作地道美式汉堡，深受当地国际社区群体的喜爱。
SHARKBURGER in Kunshan specializes in authentic American-style burgers and is a favorite among the local international community.
</p>

    <p style="margin: 0;"><strong>地理位置 Location:</strong> 昆山人才专墅 Kunshan Talent Apartment</p>
    <p style="margin: 6px 0 0;"><strong>推荐原因 Why go:</strong> 汉堡肉饼厚实多汁，面包松软，搭配地道非常纯正 The burger patties are thick and juicy, the buns are soft, and the toppings are authentically classic.
</p>
    <p style="margin: 6px 0 0;"><strong>必吃菜品 Must-try:</strong> 经典美食牛肉堡 Classic American Beef Burger</p>
    <p style="margin: 6px 0 0;"><strong>人均 Per person:</strong> ¥60</p>
    <p style="margin: 6px 0 0;"><strong>美团 Meituan:</strong> <a href="https://m.dianping.com/shopinfo/EyS8vAS3fYhmJdLK?msource=Appshare2021&utm_source=shop_share&shoptype=10&shopcategoryid=116&cityid=416&isoversea=0" target="_blank">@大众点评</a></p>
  </div>
</div>
"""

iframe5 = IFrame(html5, width=300, height=300)
popup5 = folium.Popup(iframe5, max_width=2500)

from folium.features import CustomIcon

icon5 = CustomIcon(
    icon_image="pictures/shark_logo.jpg",  # 你的 logo 路径
    icon_size=(32, 32),        # 根据图片比例调整
    icon_anchor=(16, 16)       # 控制"指针"位置
)

folium.Marker(
    location=site_5,
    popup=popup5,
    tooltip="SHARKBURGER",
    icon=icon5
).add_to(m)

# %%
m.save("kunshan_food_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
